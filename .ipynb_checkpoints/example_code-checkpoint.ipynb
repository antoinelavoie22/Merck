# %%
import matplotlib.pyplot as plt
import openslide

# %%
slide_path = '/SFS/project/kw/DigPath/HER2/HER2_ROI/HER2_status/SVS/Her2Neg_Case_02.svs'#repalce this with your image path
image=openslide.OpenSlide(slide_path)
image_dim=image.level_dimensions[-1]
thumb_img=image.get_thumbnail(image_dim)
# thumb_img.save(outpath+'/lowres.png','png') 
plt.imshow(thumb_img)
plt.show()

# %%
import sys,os
sys.path.append('/home/lilin28/Documents/HER2_Project/01_proprocessing/HistoQC/') # replace here with the HistoQC install path
import histoqc
from run_pipeline import run_pipeline

# %%
config_file = '/home/lilin28/Documents/HER2_Project/01_proprocessing/HistoQC/histoqc/config/config.ini'
filename = slide_path.split("/").pop()
base_path = slide_path.rsplit("/",1)[0]
qc_outpath = './qc/'
qc_path = qc_outpath + filename+'_mask_use.png'
num_cores = os.cpu_count()
if not os.path.exists(qc_path):
    run_pipeline(basepath = base_path,
                 input_pattern = [filename],
                 outdir = qc_outpath,
                 config_file = config_file,
                 force = True,
                 symlink = None,
                 batch = None,
                 nprocesses = num_cores)
# Out:
# 256
# 2023-02-09 11:03:59,904 - INFO - -----Working on:	/SFS/project/kw/DigPath/HER2/HER2_ROI/HER2_status/SVS/Her2Neg_Case_02.svs		1 of 1
# 2023-02-09 11:03:59,968 - INFO - Her2Neg_Case_02.svs - 	getMag
# 2023-02-09 11:04:03,480 - INFO - Her2Neg_Case_02.svs - 	getBasicStats
# 2023-02-09 11:04:03,482 - INFO - Her2Neg_Case_02.svs - 	ClassificationModule.byExample:	pen_markings
# 2023-02-09 11:04:03,484 - INFO - Her2Neg_Case_02.svs - Training model ClassificationModule.byExample:pen_markings
# 2023-02-09 11:04:58,559 - INFO - Her2Neg_Case_02.svs - Training model ClassificationModule.byExample:pen_markings....done
# 2023-02-09 11:05:16,134 - INFO - Her2Neg_Case_02.svs - 	ClassificationModule.byExample:	coverslip_edge
# 2023-02-09 11:05:16,137 - INFO - Her2Neg_Case_02.svs - Training model ClassificationModule.byExample:coverslip_edge
# 2023-02-09 11:06:25,230 - INFO - Her2Neg_Case_02.svs - Training model ClassificationModule.byExample:coverslip_edge....done
# 2023-02-09 11:06:43,059 - INFO - Her2Neg_Case_02.svs - 	LightDarkModule.getIntensityThresholdPercent:	 bright
# 2023-02-09 11:06:43,618 - INFO - Her2Neg_Case_02.svs - 	LightDarkModule.getIntensityThresholdPercent:	 dark
# 2023-02-09 11:06:43,919 - INFO - Her2Neg_Case_02.svs - 	BubbleRegionByRegion.detectSmoothness
# 2023-02-09 11:06:44,888 - INFO - Her2Neg_Case_02.svs - 	removeFatlikeTissue
# 2023-02-09 11:06:45,482 - INFO - Her2Neg_Case_02.svs - 	fillSmallHoles
# 2023-02-09 11:06:45,766 - INFO - Her2Neg_Case_02.svs - 	removeSmallObjects
# 2023-02-09 11:06:46,013 - INFO - Her2Neg_Case_02.svs - 	identifyBlurryRegions
# 2023-02-09 11:07:00,198 - INFO - Her2Neg_Case_02.svs - 	finalProcessingSpur
# 2023-02-09 11:07:00,571 - INFO - Her2Neg_Case_02.svs - 	finalProcessingArea
# 2023-02-09 11:07:00,674 - INFO - Her2Neg_Case_02.svs - 	compareToTemplates
# 2023-02-09 11:07:00,760 - INFO - Her2Neg_Case_02.svs - 	getHistogram
# 2023-02-09 11:07:00,897 - INFO - Her2Neg_Case_02.svs - 	getContrast:
# 2023-02-09 11:07:01,009 - INFO - Her2Neg_Case_02.svs - 	getContrast:
# 2023-02-09 11:07:01,031 - INFO - Her2Neg_Case_02.svs - 	getContrast:
# 2023-02-09 11:07:01,036 - INFO - Her2Neg_Case_02.svs - 	getContrast:
# 2023-02-09 11:07:01,079 - INFO - Her2Neg_Case_02.svs - 	separateStains
# 2023-02-09 11:07:01,812 - INFO - Her2Neg_Case_02.svs - 	saveUsableRegion
# 2023-02-09 11:07:03,670 - INFO - Her2Neg_Case_02.svs - 	saveThumbnail
# 2023-02-09 11:07:06,425 - INFO - Her2Neg_Case_02.svs - 		creating image thumb of size 500.0
